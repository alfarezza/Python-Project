# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ryana\Downloads\salaries.csv")
# Tampilkan semua kolom dan baris
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#         work_year experience_level employment_type                  job_title  \
# 0            2025               MI              FT             Data Scientist
# 1            2025               MI              FT             Data Scientist
# 2            2025               SE              FT       Data Product Manager
# 3            2025               SE              FT       Data Product Manager
# 4            2025               SE              FT  Machine Learning Engineer
# ...           ...              ...             ...                        ...
# 136752       2020               SE              FT             Data Scientist
# 136753       2021               MI              FT   Principal Data Scientist
# 136754       2020               EN              FT             Data Scientist
# 136755       2020               EN              CT      Business Data Analyst
# 136756       2021               SE              FT             Data Scientist
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0        132600             USD         132600                 US
# 1        102000             USD         102000                 US
# 2        260520             USD         260520                 US
# 3        140280             USD         140280                 US
# 4        215000             USD         215000                 US
# ...         ...             ...            ...                ...
# 136752   412000             USD         412000                 US
# 136753   151000             USD         151000                 US
# 136754   105000             USD         105000                 US
# 136755   100000             USD         100000                 US
# 136756  7000000             INR          94665                 IN
#
#         remote_ratio company_location company_size
# 0                100               US            M
# 1                100               US            M
# 2                  0               US            M
# 3                  0               US            M
# 4                  0               US            M
# ...              ...              ...          ...
# 136752           100               US            L
# 136753           100               US            L
# 136754           100               US            S
# 136755           100               US            L
# 136756            50               IN            L
#
# [136757 rows x 11 columns]

# %%
df['work_year'].unique()
# Out:
# array([2025, 2024, 2022, 2023, 2020, 2021])

# %%
df['experience_level'].unique()
# Out:
# array(['MI', 'SE', 'EN', 'EX'], dtype=object)

# %%
df['employment_type'].unique()
# Out:
# array(['FT', 'CT', 'PT', 'FL'], dtype=object)

# %%
df['salary_currency'].unique()
# Out:
# array(['USD', 'EUR', 'GBP', 'CAD', 'MXN', 'PLN', 'CHF', 'PHP', 'JPY',
#        'INR', 'SGD', 'HUF', 'AUD', 'TWD', 'NOK', 'BRL', 'CZK', 'ZAR',
#        'DKK', 'ILS', 'TRY', 'SEK', 'NZD', 'HKD', 'THB', 'CLP'],
#       dtype=object)

# %%
df['employee_residence'].unique()
# Out:
# array(['US', 'CA', 'AT', 'LV', 'GB', 'PT', 'FI', 'AU', 'NZ', 'SK', 'IE',
#        'ES', 'DE', 'NL', 'PL', 'FR', 'BR', 'ZA', 'AR', 'CO', 'MX', 'UA',
#        'CH', 'LT', 'PH', 'BE', 'TH', 'JM', 'JP', 'MT', 'IT', 'MK', 'SI',
#        'HK', 'LS', 'IN', 'ID', 'PE', 'SG', 'HU', 'RO', 'PA', 'EE', 'LU',
#        'DZ', 'EG', 'CL', 'GR', 'KE', 'CD', 'SE', 'KR', 'TW', 'NO', 'CZ',
#        'TR', 'NG', 'CY', 'DK', 'AE', 'BG', 'JO', 'RS', 'PR', 'SV', 'EC',
#        'DO', 'MY', 'XK', 'CR', 'ZM', 'AM', 'RW', 'IL', 'LB', 'HR', 'PK',
#        'HN', 'VE', 'BM', 'VN', 'GE', 'SA', 'OM', 'BA', 'UG', 'MU', 'QA',
#        'RU', 'TN', 'GH', 'AD', 'MD', 'UZ', 'CF', 'KW', 'IR', 'AS', 'CN',
#        'BO', 'IQ', 'JE'], dtype=object)

# %%
df['remote_ratio'].unique()
# Out:
# array([100,   0,  50])

# %%
df['company_location'].unique()
# Out:
# array(['US', 'CA', 'AT', 'LV', 'GB', 'PT', 'FI', 'AU', 'NZ', 'SK', 'IE',
#        'ES', 'DE', 'NL', 'PL', 'FR', 'BR', 'ZA', 'AR', 'CO', 'MX', 'UA',
#        'CH', 'LT', 'PH', 'BE', 'TH', 'JM', 'JP', 'MT', 'MK', 'SI', 'HK',
#        'LS', 'IN', 'PE', 'SG', 'IT', 'HU', 'RO', 'PA', 'EE', 'LU', 'DZ',
#        'EG', 'CL', 'GR', 'KE', 'CD', 'SE', 'KR', 'TW', 'NO', 'CZ', 'TR',
#        'CY', 'DK', 'AE', 'BG', 'ID', 'JO', 'RS', 'PR', 'SV', 'EC', 'DO',
#        'MY', 'XK', 'CR', 'ZM', 'AM', 'IL', 'LB', 'NG', 'HR', 'PK', 'HN',
#        'VE', 'AS', 'SA', 'OM', 'BA', 'VN', 'GI', 'MU', 'RU', 'QA', 'GH',
#        'AD', 'CF', 'IR', 'BS', 'IQ', 'CN', 'MD'], dtype=object)

# %%
df['company_size'].unique()
# Out:
# array(['M', 'L', 'S'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136757 entries, 0 to 136756
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           136757 non-null  int64
#  1   experience_level    136757 non-null  object
#  2   employment_type     136757 non-null  object
#  3   job_title           136757 non-null  object
#  4   salary              136757 non-null  int64
#  5   salary_currency     136757 non-null  object
#  6   salary_in_usd       136757 non-null  int64
#  7   employee_residence  136757 non-null  object
#  8   remote_ratio        136757 non-null  int64
#  9   company_location    136757 non-null  object
#  10  company_size        136757 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 11.5+ MB

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.shape
# Out:
# (136757, 11)

# %%
# Statistical summary of numerical columns
df.describe().T.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_587a8_row0_col0, #T_587a8_row0_col2, #T_587a8_row0_col7, #T_587a8_row1_col0, #T_587a8_row2_col0, #T_587a8_row3_col0, #T_587a8_row3_col1, #T_587a8_row3_col2, #T_587a8_row3_col3, #T_587a8_row3_col4, #T_587a8_row3_col5, #T_587a8_row3_col6, #T_587a8_row3_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_587a8_row0_col1, #T_587a8_row0_col5 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_587a8_row0_col3 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_587a8_row0_col4 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_587a8_row0_col6 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_587a8_row1_col1, #T_587a8_row1_col2, #T_587a8_row1_col4, #T_587a8_row1_col5, #T_587a8_row1_col6, #T_587a8_row1_col7, #T_587a8_row2_col3, #T_587a8_row2_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_587a8_row1_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_587a8_row2_col1 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_587a8_row2_col2 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_587a8_row2_col5, #T_587a8_row2_col6 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_587a8_row2_col7 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# </style>
# <table id="T_587a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_587a8_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_587a8_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_587a8_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_587a8_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_587a8_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_587a8_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_587a8_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_587a8_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_587a8_level0_row0" class="row_heading level0 row0" >work_year</th>
#       <td id="T_587a8_row0_col0" class="data row0 col0" >136757.000000</td>
#       <td id="T_587a8_row0_col1" class="data row0 col1" >2024.374686</td>
#       <td id="T_587a8_row0_col2" class="data row0 col2" >0.679644</td>
#       <td id="T_587a8_row0_col3" class="data row0 col3" >2020.000000</td>
#       <td id="T_587a8_row0_col4" class="data row0 col4" >2024.000000</td>
#       <td id="T_587a8_row0_col5" class="data row0 col5" >2024.000000</td>
#       <td id="T_587a8_row0_col6" class="data row0 col6" >2025.000000</td>
#       <td id="T_587a8_row0_col7" class="data row0 col7" >2025.000000</td>
#     </tr>
#     <tr>
#       <th id="T_587a8_level0_row1" class="row_heading level0 row1" >salary</th>
#       <td id="T_587a8_row1_col0" class="data row1 col0" >136757.000000</td>
#       <td id="T_587a8_row1_col1" class="data row1 col1" >163043.175304</td>
#       <td id="T_587a8_row1_col2" class="data row1 col2" >215043.504333</td>
#       <td id="T_587a8_row1_col3" class="data row1 col3" >14000.000000</td>
#       <td id="T_587a8_row1_col4" class="data row1 col4" >106000.000000</td>
#       <td id="T_587a8_row1_col5" class="data row1 col5" >147000.000000</td>
#       <td id="T_587a8_row1_col6" class="data row1 col6" >198800.000000</td>
#       <td id="T_587a8_row1_col7" class="data row1 col7" >30400000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_587a8_level0_row2" class="row_heading level0 row2" >salary_in_usd</th>
#       <td id="T_587a8_row2_col0" class="data row2 col0" >136757.000000</td>
#       <td id="T_587a8_row2_col1" class="data row2 col1" >157490.722756</td>
#       <td id="T_587a8_row2_col2" class="data row2 col2" >74173.546839</td>
#       <td id="T_587a8_row2_col3" class="data row2 col3" >15000.000000</td>
#       <td id="T_587a8_row2_col4" class="data row2 col4" >105900.000000</td>
#       <td id="T_587a8_row2_col5" class="data row2 col5" >146000.000000</td>
#       <td id="T_587a8_row2_col6" class="data row2 col6" >197800.000000</td>
#       <td id="T_587a8_row2_col7" class="data row2 col7" >800000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_587a8_level0_row3" class="row_heading level0 row3" >remote_ratio</th>
#       <td id="T_587a8_row3_col0" class="data row3 col0" >136757.000000</td>
#       <td id="T_587a8_row3_col1" class="data row3 col1" >20.909716</td>
#       <td id="T_587a8_row3_col2" class="data row3 col2" >40.594326</td>
#       <td id="T_587a8_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_587a8_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_587a8_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_587a8_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_587a8_row3_col7" class="data row3 col7" >100.000000</td>
#     </tr>
#   </tbody>
# </table>
