# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\ryana\Downloads\USC00255362.csv")
pd.set_option('display.max_columns', None)

# %%
df.sample(5)
# Out:
#         STATION  DATE  LATITUDE  LONGITUDE  ELEVATION             NAME   CDSD  \
# 41  USC00255362  2013    41.143   -96.4808      356.6  MEAD 6 S, NE US  552.2
# 48  USC00255362  2020    41.143   -96.4808      356.6  MEAD 6 S, NE US  562.4
# 24  USC00255362  1996    41.143   -96.4808      356.6  MEAD 6 S, NE US  404.4
# 37  USC00255362  2009    41.143   -96.4808      356.6  MEAD 6 S, NE US  325.0
# 3   USC00255362  1972    41.143   -96.4808      356.6  MEAD 6 S, NE US  498.2
#
#     CDSD_ATTRIBUTES   CLDD CLDD_ATTRIBUTES  DP01 DP01_ATTRIBUTES  DP10  \
# 41              NaN  552.2               7  73.0               7  51.0
# 48              NaN  562.4               7  74.0               7  45.0
# 24              NaN  404.4               0  95.0               0  55.0
# 37              NaN  325.0               0  87.0               0  50.0
# 3               NaN  498.2               0  90.0               0  54.0
#
# ...
