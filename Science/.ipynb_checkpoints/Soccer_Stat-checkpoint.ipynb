# %% [markdown]
# ### Load Dataset

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\ryana\Downloads\DataSet\matches_full.csv")
pd.set_option('display.max_columns', None)

# %%
data.sample()
# Out:
#       Unnamed: 0        date   time     comp         round  day venue result  \
# 3315          29  2021-02-20  16:15  La Liga  Matchweek 24  Sat  Away      W
#
#        gf   ga         opponent   xg  xga  poss  attendance  \
# 3315  2.0  0.0  Atlético Madrid  0.8  2.1  44.0         NaN
#
#                 captain formation opp formation       referee  match report  \
# 3315  José Luis Morales     3-4-3         3-4-3  Mario Melero  Match Report
#
#       notes   sh  sot  dist   fk  pk  pkatt  season     team
# 3315    NaN  6.0  1.0  21.4  0.0   0      0    2021  Levante

# %% [markdown]
# ### Data Pre-Processing

# %%
data = data.drop(['Unnamed: 0'], axis=1)
data = data.drop(['comp'], axis=1)
data = data.drop(['captain'], axis=1)
data = data.drop(['referee'], axis=1)
data = data.drop(['match report'], axis=1)
data = data.drop(['notes'], axis=1)

# %%
data.sample()
# Out:
#            date   time         round  day venue result   gf   ga  \
# 762  2023-12-17  16:15  Matchweek 17  Sun  Away      D  0.0  0.0
#
#           opponent   xg  xga  poss  attendance formation opp formation    sh  \
# 762  Real Sociedad  1.1  1.1  43.0     33172.0   4-2-3-1         4-3-3  12.0
#
#      sot  dist   fk  pk  pkatt  season        team
# 762  3.0  15.7  0.0   0      0    2024  Real Betis

# %%
# Standarized Value in 'formation' column
data['formation'].unique()
# Out:
# array(['4-2-3-1', '4-3-3', '4-1-4-1', '3-4-3', '5-3-2', '4-4-2', '5-4-1',
#        '4-1-2-1-2◆', '4-4-1-1', '4-2-2-2', '4-5-1', '3-5-2', '3-5-1-1',
#        '3-1-4-2', '3-4-3◆', '3-4-1-2', '4-1-3-2', '4-3-1-2', '3-2-4-1',
#        '4-3-2-1', '4-2-4-0', '3-3-3-1'], dtype=object)

# %%
# Membersihkan simbol tidak diperlukan, misalnya ◆
data['formation'] = data['formation'].str.replace('◆', '', regex=False)

# %%
data['formation'] = data['formation'].replace('4-2-4-0', '4-2-4')

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data['time'] = pd.to_datetime(data['time'], format = '%H:%M').dt.time

# %%
# data_model['formation'] = data_model['formation'].astype('category')

# %%
data['opponent'] = data['opponent'].astype('category')

# %%
# change the data type to int
data['sh'] = data['sh'].astype(int)
data['sot'] = data['sot'].astype(int)
data['ga'] = data['ga'].astype(int)
data['gf'] = data['gf'].astype(int)
data['fk'] = data['fk'].astype(int)

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                        int64
# ga                        int64
# opponent               category
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# formation                object
# opp formation            object
# sh                        int64
# sot                       int64
# dist                    float64
# fk                        int64
# pk                        int64
# pkatt                     int64
# season                    int64
# team                     object
# dtype: object

# %%
data.isnull().sum()
# Out:
# date               0
# time               0
# round              0
# day                0
# venue              0
# result             0
# gf                 0
# ga                 0
# opponent           0
# xg                 0
# xga                0
# poss               0
# attendance       974
# formation          0
# opp formation      0
# sh                 0
# sot                0
# dist               3
# fk                 0
# pk                 0
# pkatt              0
# season             0
# team               0
# dtype: int64

# %%
data['attendance'] = data.groupby(['team', 'venue', 'opponent'])['attendance'].transform(
    lambda x: x.fillna(x.median())
)
# Out:
# C:\Users\ryana\AppData\Local\Temp\ipykernel_16320\321960465.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data['attendance'] = data.groupby(['team', 'venue', 'opponent'])['attendance'].transform(
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\ryana\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
# we still got the null value, then we will imputation with median techic
data['attendance'] = data['attendance'].fillna(data['attendance'].median())

# %%
# change the data type to int
data['attendance'] = data['attendance'].astype(int)

# %%
data['dist'] = data.groupby(['venue', 'team'])['dist'].transform(
    lambda x: x.fillna(x.mean())
)

# %%
data.isnull().sum()
# Out:
# date             0
# time             0
# round            0
# day              0
# venue            0
# result           0
# gf               0
# ga               0
# opponent         0
# xg               0
# xga              0
# poss             0
# attendance       0
# formation        0
# opp formation    0
# sh               0
# sot              0
# dist             0
# fk               0
# pk               0
# pkatt            0
# season           0
# team             0
# dtype: int64

# %% [markdown]
# ## Machine Learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
data_model = data.copy()

# %%
data_model = data_model.drop('time', axis=1)

# %%
data_model.sample(3)
# Out:
#            date         round  day venue result  gf  ga    opponent   xg  xga  \
# 3120 2021-01-20  Matchweek 19  Wed  Away      D   2   2  Villarreal  0.2  2.4
# 3162 2021-02-21  Matchweek 24  Sun  Home      D   1   1  Villarreal  2.6  0.1
# 1022 2023-11-04  Matchweek 12  Sat  Away      D   1   1  Celta Vigo  0.9  2.1
#
#       poss  attendance formation opp formation  sh  sot  dist  fk  pk  pkatt  \
# 3120  32.0       14753   4-1-4-1         4-3-3   3    2  15.2   0   0      0
# 3162  48.0       46081     4-4-2         4-4-2  18    8  17.9   1   0      0
# 1022  61.0       19023     4-3-3         4-4-2  13    5  15.8   0   0      0
#
#       season           team
# 3120    2021        Granada
# 3162    2021  Athletic Club
# 1022    2024        Sevilla

# %% [markdown]
# ##### Feature Enggineering

# %%
result_map = {'W':2, 'D':1, 'L':0}
data_model['target_pred'] = data_model['result'].map(result_map)

# %%
data_model.sample(5)
# Out:
#            date         round  day venue result  gf  ga         opponent   xg  \
# 2564 2022-04-21  Matchweek 33  Thu  Home      L   0   1   Rayo Vallecano  0.4
# 1970 2022-10-16   Matchweek 9  Sun  Home      W   1   0       Valladolid  1.3
# 111  2024-09-30   Matchweek 8  Mon  Home      W   3   1       Las Palmas  2.8
# 2033 2023-05-14  Matchweek 34  Sun  Home      W   1   0  Atlético Madrid  1.4
# 1411 2023-02-05  Matchweek 20  Sun  Home      L   0   1       Valladolid  1.2
#
#       xga  poss  attendance formation opp formation  sh  sot  dist  fk  pk  \
# 2564  0.6  57.0       11873     4-3-3       4-2-3-1   6    2  17.9   0   0
# 1970  0.7  49.0       17770   4-1-3-2         4-3-3  15    3  17.6   1   0
# 111   0.9  43.0       18159     4-4-2         4-4-2  19    6  15.2   0   0
# 2033  1.5  49.0       22174   3-4-1-2         3-5-2  15    4  13.4   0   0
# 1411  0.7  55.0       32214   4-3-2-1       4-2-3-1  15    4  19.4   1   0
#
#       pkatt  season           team  target_pred
# 2564      0    2022       Espanyol            0
# 1970      0    2023       Espanyol            2
# 111       1    2025     Villarreal            2
# 2033      0    2023          Elche            2
# 1411      0    2023  Real Sociedad            0

# %%
# Selisih expected goals (indikator kekuatan serangan vs pertahanan)
data_model['xg_diff'] = data_model['xg'] - data_model['xga']
data_model['sh_accuracy'] = data_model['sot'] / data_model['sh'].replace(0, 1)
data_model['conversion_rate'] = data_model['gf'] / data_model['sh'].replace(0, 1)

# Penalty Convension Rate (PCR)
data_model['PCR'] = data_model['pk'] / data_model['pkatt'].replace(0, 1)

#Finishing Efficiency
data_model['finishing_efficiency'] = data_model['gf'] / data_model['xg'].replace(0, 1)

data_model['sh_per_poss'] = data_model['sh'] / data_model['poss'].replace(0, 1) #Shots per Possession (%) → Efisiensi menciptakan peluang berdasarkan penguasaan bola.
data_model['sot_per_xg'] = data_model['sot'] / data_model['xg'].replace(0, 1) #Shots on Target per xG → Apakah tim memanfaatkan peluang xG untuk menghasilkan tembakan tepat sasaran.
data_model['fk_per_sh'] = data_model['fk'] / data_model['sh'].replace(0, 1) #Free Kick per Shot

# %% [markdown]
# ##### Filtering the best Feature

# %%
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cols = [
    'gf','ga', 'xg', 'xga',	'poss',	'attendance', 
    'sh', 'sot','fk', 'pk',	'pkatt', 'xg_diff',	'sh_accuracy',	'conversion_rate',	
    'PCR', 'finishing_efficiency', 'sh_per_poss', 'sot_per_xg',	'fk_per_sh'
]

# cols = [
#     'gf','ga', 'conversion_rate','finishing_efficiency' 
# ]

train_data = data_model[cols]
test_data = data_model['target_pred']

# %%
# Buat model dan latih
model = RandomForestRegressor()
model.fit(train_data, test_data)
# Out:
# RandomForestRegressor()

# %%
feature_importance = model.feature_importances_

# Tampilkan dalam DataFrame
importance_df = pd.DataFrame({
    'Fitur': train_data.columns,
    'Importance': feature_importance
}).sort_values(by='Importance', ascending=False)

# %%
# Visualisasikan
plt.figure(figsize=(6,4))
sns.barplot(x='Importance', y='Fitur', data=importance_df)
plt.title('Feature Importance - Random Forest')
plt.show()

# %% [markdown]
# ##### Split Data Train and Data Test

# %%
y = data_model['target_pred'].astype(int)  # make sure data type in int and value is 0, 1, 2
X = data_model[['ga', 'conversion_rate', 'PCR', 'finishing_efficiency', 'sh_per_poss']]
# X = data_model[[ 'conversion_rate', 'PCR', 'finishing_efficiency', 'gf', 'sh_accuracy', 'sot_per_xg']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42, test_size=0.2)

# %%
y_test.head()
# Out:
# 2291    2
# 1817    0
# 2688    1
# 3137    0
# 1567    1
# Name: target_pred, dtype: int64

# %% [markdown]
# ##### ➡️ Try using Random Forest Method

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       314
#            1       0.90      0.89      0.89       237
#            2       0.95      0.94      0.94       313
#
#     accuracy                           0.94       864
#    macro avg       0.94      0.94      0.94       864
# weighted avg       0.94      0.94      0.94       864
#
# [[311   3   0]
#  [ 10 210  17]
#  [  0  20 293]]

# %% [markdown]
# 📌Summary:
#
# The model is already accurate in distinguishing the three classes, including the often problematic “series” class. But there is still room for improvisation and improvement to a more robust and generalization-tested model.

# %%
clf.predict_proba(X_test)
# Out:
# array([[0.  , 0.  , 1.  ],
#        [1.  , 0.  , 0.  ],
#        [0.  , 0.03, 0.97],
#        ...,
#        [0.  , 0.01, 0.99],
#        [0.  , 0.  , 1.  ],
#        [0.89, 0.11, 0.  ]], shape=(864, 3))

# %% [markdown]
# ✅ Use Stratified K-Fold Cross-Validation
#
# For fairer validation and even distribution of labels in each fold:

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
clf = RandomForestClassifier(random_state=42)

scores = cross_val_score(clf, X, y, cv=skf, scoring='f1_macro')
print("F1-macro per fold:", scores)
print("Mean F1-macro:", scores.mean())
# Out:
# F1-macro per fold: [0.94197563 0.9382791  0.9356607  0.94703113 0.94873616]
# Mean F1-macro: 0.942336544920682

# %% [markdown]
# ##### Tuning Random Forest

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [300],
    'max_depth': [None],
    'min_samples_split': [2],
    'class_weight': ['balanced']
}

grid = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=skf, scoring='f1_macro')
grid.fit(X, y)

print("Best parameters:", grid.best_params_)
print("Best F1-macro score:", grid.best_score_)
# Out:
# Best parameters: {'class_weight': 'balanced', 'max_depth': None, 'min_samples_split': 2, 'n_estimators': 300}
# Best F1-macro score: 0.9433254543215798

# %%
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

models = {
    "Random Forest": RandomForestClassifier(random_state=42),
    "XGBoost": XGBClassifier(eval_metric='mlogloss'),
    "Logistic Regression": LogisticRegression(max_iter=500)
}

for name, model in models.items():
    scores = cross_val_score(model, X, y, cv=skf, scoring='f1_macro')
    print(f"{name}: Mean F1-macro = {scores.mean():.4f}")
# Out:
# Random Forest: Mean F1-macro = 0.9423
# XGBoost: Mean F1-macro = 0.9437
# Logistic Regression: Mean F1-macro = 0.8860

# %%
from sklearn.ensemble import RandomForestClassifier

final_model = RandomForestClassifier(
    class_weight='balanced',
    max_depth=None,
    min_samples_split=2,
    n_estimators=300,
    random_state=42
)

final_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=300,
#                        random_state=42)

# %% [markdown]
# ##### Confusion Matrix

# %%
# Prediksi pada data test
y_pred = final_model.predict(X_test)

# Tampilkan classification report
print("=== Classification Report ===")
print(classification_report(y_test, y_pred))

# Tampilkan confusion matrix
print("=== Confusion Matrix ===")
print(confusion_matrix(y_test, y_pred))
# Out:
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       314
#            1       0.91      0.89      0.90       237
#            2       0.94      0.94      0.94       313
#
#     accuracy                           0.94       864
#    macro avg       0.94      0.94      0.94       864
# weighted avg       0.94      0.94      0.94       864
#
# === Confusion Matrix ===
# [[311   3   0]
#  [  9 210  18]
#  [  0  19 294]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

labels = ['Kalah', 'Seri', 'Menang']
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ##### Result & Conclusion

# %%
# 1. Buat DataFrame hasil prediksi vs aktual
df_result = pd.DataFrame({
    'Actual': y_test.values,
    'Predicted': y_pred
})

# %%
# 2. (Opsional) Tambahkan probabilitas
y_proba = final_model.predict_proba(X_test)

df_result['Prob_Kalah'] = y_proba[:, 0]
df_result['Prob_Seri'] = y_proba[:, 1]
df_result['Prob_Menang'] = y_proba[:, 2]

# %%
# 3. (Opsional) Tambahkan fitur input yang digunakan
cols1 = [
    'date', 'venue', 'team', 'gf', 'ga','opponent',	'poss', 'result', 'attendance', 'season'	
]

# df_features = X_test.reset_index(drop=True)
# df_features1 = data_model[cols1].reset_index(drop=True)
# df_result = pd.concat([df_features1.reset_index(drop=True), df_result.reset_index(drop=True)], axis=1)

df_features = X_test.reset_index(drop=True)
df_result = pd.concat([df_features.reset_index(drop=True), df_result.reset_index(drop=True)], axis=1)

# %%
# 4. Tampilkan 10 baris pertama
df_result.sample(6)
# Out:
#      ga  conversion_rate  PCR  finishing_efficiency  sh_per_poss  Actual  \
# 425   1         0.000000  0.0              0.000000     0.188679       0
# 373   1         0.117647  0.0              0.952381     0.250000       2
# 549   2         0.117647  1.0              0.909091     0.257576       1
# 280   0         0.000000  0.0              0.000000     0.211268       1
# 599   3         0.142857  0.0              1.666667     0.205882       0
# 566   1         0.000000  0.0              0.000000     0.142857       0
#
#      Predicted  Prob_Kalah  Prob_Seri  Prob_Menang
# 425          0    1.000000   0.000000     0.000000
# 373          2    0.000000   0.183333     0.816667
# 549          1    0.120000   0.866667     0.013333
# 280          1    0.000000   1.000000     0.000000
# 599          0    0.963333   0.036667     0.000000
# 566          0    1.000000   0.000000     0.000000

# %%
df_result[df_result['Actual'] != df_result['Predicted']].sample(5)
# Out:
#      ga  conversion_rate  PCR  finishing_efficiency  sh_per_poss  Actual  \
# 208   2         0.285714  1.0              1.250000     0.205882       1
# 486   2         0.222222  0.0              3.333333     0.333333       1
# 172   2         0.285714  0.0              2.000000     0.194444       1
# 86    3         0.333333  0.0              2.142857     0.375000       1
# 553   2         0.166667  0.0              1.818182     0.400000       1
#
#      Predicted  Prob_Kalah  Prob_Seri  Prob_Menang
# 208          2    0.013333   0.230000     0.756667
# 486          2    0.026667   0.276667     0.696667
# 172          2    0.043333   0.363333     0.593333
# 86           2    0.126667   0.070000     0.803333
# 553          2    0.006667   0.433333     0.560000

# %% [markdown]
# #### Conclusion
