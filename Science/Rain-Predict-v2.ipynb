# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\ryana\Downloads\DataSet\weatherAUS_rainfall_prediction_dataset_cleaned.csv")
pd.set_option('display.max_column', None)

# %%
df.sample()
# Out:
#               Date     Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 121772  2017-01-29  Tuggeranong     13.2     36.1       0.0         5.47
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 121772      7.61         ENE           37.0        WNW         NW
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 121772           6.0          13.0         51.0         16.0       1016.5
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday  \
# 121772       1012.6      4.45      4.51     21.9     35.2        No
#
#        RainTomorrow
# 121772           No

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df.drop(columns=['Date'], inplace=True)

# %%
df.sample()
# Out:
#            Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 67245  MountGambier      8.3     15.2       1.2          1.0      7.61
#
#       WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 67245         NNE           61.0        NNE        NNE          22.0
#
#        WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 67245          31.0         93.0         80.0       1012.9       1006.7
#
#        Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday RainTomorrow  Year  \
# 67245       6.0       8.0     12.2     14.2       Yes          Yes  2011
#
#        Month  Day
# 67245      8   16

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Import Library

# %%
# Preprocessing
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Model
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# Train-test split & evaluasi
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Imbalance handling
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline

# %% [markdown]
# ## Split Train / Test

# %%
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']

# Tentukan kolom kategorikal & numerik
cat_cols = X.select_dtypes(include=['object']).columns.tolist()
num_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()

# %% [markdown]
# ## Data Pre-processing

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols)
    ]
)

# %% [markdown]
# ## Pipeline SMOTE + Model

# %% [markdown]
# ### RandomForest

# %%
# Contoh dengan RandomForest
rf_pipeline = ImbPipeline(steps=[
    ('preprocessor', preprocessor),
    ('smote', SMOTE(random_state=42)),
    ('classifier', RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42))
])

# %% [markdown]
# ### Logistic Regression

# %%
lr_pipeline = ImbPipeline(steps=[
    ('preprocessor', preprocessor),
    ('smote', SMOTE(random_state=42)),
    ('classifier', LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42))
])

# %% [markdown]
# ### XgBoost
