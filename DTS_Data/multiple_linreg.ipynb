# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Create the dataset
data = {
    'Hours_Studied': [1, 2, 3, 4, 5, 6, 7],
    'Attendance_Rate': [85, 90, 95, 85, 90, 88, 93],
    'Practice_Tests_Taken': [1, 2, 3, 4, 5, 6, 5],
    'Final_Score': [52, 58, 64, 67, 73, 78, 87]
}

# %%
# convert data to dataframe
df = pd.DataFrame(data)

# %%
df
# Out:
#    Hours_Studied  Attendance_Rate  Practice_Tests_Taken  Final_Score
# 0              1               85                     1           52
# 1              2               90                     2           58
# 2              3               95                     3           64
# 3              4               85                     4           67
# 4              5               90                     5           73
# 5              6               88                     6           78
# 6              7               93                     5           87
