# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
URL = "https://www.periplus.com/c/1/books?page=1&anl=202&sar=1"

# %%
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36', 'Accept-Language':'en-US'})

# %%
#HTTPS Requ
webpage = requests.get(URL, headers = HEADERS)

# %%
type(webpage.content)
# Out:
# bytes

# %%
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# Fetch Link
#soup.find_all("a")
soup.find_all("h3", attrs={'href'})
#'div', class_='product-author author-category').find_all('a')

# %%
# Temukan semua tag h3
h3_tags = soup.find_all("h3")

for h3 in h3_tags:
    a_tag = h3.find("a")
    link = a_tag.get['href']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 6
#       4 for h3 in h3_tags:
#       5     a_tag = h3.find("a")
# ----> 6     link = a_tag.get['href']
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
a_tag

# %%
soup.find_all("h3", attrs='a')
# Out:
# []

# %%
new_webpage = requests.get(link_href, headers=HEADERS)

# %%
a_tag= []

for h3 in soup.find_all('h3'):
    a_tag = h3.find('a')

# %%
a_tag
# Out:
# <a href="http://www.periplus.com/p/9781580627566/why-men-love-bitches-from-doormat-to-dreamgirl-a-woman-s-guide-to-holding-her-own-in-a-relationship?path=1">Why Men Love Bitches: From Doormat to Dreamgirl--A...</a>
